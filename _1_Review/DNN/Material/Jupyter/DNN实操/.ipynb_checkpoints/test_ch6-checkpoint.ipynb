# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision import datasets
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 展示高清图
from matplotlib_inline import backend_inline
backend_inline.set_matplotlib_formats('svg')

# %%
# 制作数据集
# 数据集转换参数
transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize(0.1307, 0.3081)
])
# 下载训练集与测试集
train_Data = datasets.MNIST(
    root = 'D:/Jupyter/dataset/mnist/', # 下载路径
    train = True, # 是 train 集
    download = True, # 如果该路径没有该数据集，就下载
    transform = transform # 数据集转换参数
)
test_Data = datasets.MNIST(
    root = 'D:/Jupyter/dataset/mnist/', # 下载路径
    train = False, # 是 test 集
    download = True, # 如果该路径没有该数据集，就下载
    transform = transform # 数据集转换参数
)

# %%
# 批次加载器
train_loader = DataLoader(dataset=train_Data, shuffle=True, batch_size=64)
test_loader = DataLoader(dataset=test_Data, shuffle=False, batch_size=32)

# %%
# 搭建神经网络
class DNN(nn.Module):
    def __init__(self):
        ''' 搭建神经网络各层 '''
        super(DNN, self).__init__()
        self.net = nn.Sequential(   # 按顺序搭建各层
            nn.Flatten(),                    # 把图像铺平成一维
            nn.Linear(784, 512), nn.ReLU(),  # 第 1 层：全连接层
            nn.Linear(512, 256), nn.ReLU(),  # 第 2 层：全连接层
            nn.Linear(256, 128), nn.ReLU(),  # 第 3 层：全连接层
            nn.Linear(128, 64), nn.ReLU(),   # 第 4 层：全连接层
            nn.Linear(64, 10)                # 第 5 层：全连接层
        )

    def forward(self, x):
        ''' 前向传播 '''
        y = self.net(x)  # x 即输入数据, 这里的net和__init__()中的net要一致，自己起名
        return y         # y 即输出数据

# %%
model = DNN().to('cuda:0') # 创建子类的实例，并搬到 GPU 上
model # 查看该实例的各层
# Out:
# DNN(
#   (net): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=784, out_features=512, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=512, out_features=256, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=256, out_features=128, bias=True)
#     (6): ReLU()
#     (7): Linear(in_features=128, out_features=64, bias=True)
#     (8): ReLU()
#     (9): Linear(in_features=64, out_features=10, bias=True)
#     (10): Softmax(dim=1)
#   )
# )

# %%
# 损失函数的选择
loss_fn = nn.CrossEntropyLoss() # 自带 softmax 激活函数

# %%
# 优化算法的选择
learning_rate = 0.01 # 设置学习率
optimizer = torch.optim.SGD(
    model.parameters(),
    lr = learning_rate,
    momentum = 0.5   
)

# %%
# 训练网络
epochs = 5
losses = [] # 记录损失函数变化的列表

for epoch in range(epochs):
    for (x, y) in train_loader: # 获取小批次的 x 与 y
        x, y = x.to('cuda:0'), y.to('cuda:0')
        Pred = model(x) # 一次前向传播（小批量）
        loss = loss_fn(Pred, y) # 计算损失函数
        losses.append(loss.item()) # 记录损失函数的变化
        optimizer.zero_grad() # 清理上一轮滞留的梯度
        loss.backward() # 一次反向传播
        optimizer.step() # 优化内部参数
        
Fig = plt.figure()
plt.plot(range(len(losses)), losses)
plt.show()

# %%
# 测试网络
correct = 0
total = 0
with torch.no_grad(): # 该局部关闭梯度计算功能
    for (x, y) in test_loader: # 获取小批次的 x 与 y
        x, y = x.to('cuda:0'), y.to('cuda:0')
        Pred = model(x) # 一次前向传播（小批量）
        _, predicted = torch.max(Pred.data, dim=1)
        correct += torch.sum( (predicted == y) )
        total += y.size(0) 
print(f'测试集精准度: {100*correct/total} %')
# Out:
# 测试集精准度: 73.45999908447266 %

# %%
# 测试网络
correct = 0
total = 0
with torch.no_grad(): # 该局部关闭梯度计算功能
    for (x, y) in test_loader: # 获取小批次的 x 与 y
        x, y = x.to('cuda:0'), y.to('cuda:0')   
        Pred = model(x) # 一次前向传播（小批量）
        print(Pred.type(), y.type())  
        print(Pred.shape, y.shape)       
        _, predicted = torch.max(Pred.data, dim=1)
        print(predicted.type(), y.type())  
        print(predicted.shape, y.shape)      
        print((predicted == y).all(1).type())   
        print((predicted == y).all(1).shape)    
        correct += torch.sum( (predicted == y) )
        total += y.size(0) 
print(f'测试集精准度: {100*correct/total} %')
# Out:
# torch.cuda.FloatTensor torch.cuda.LongTensor
# torch.Size([32, 10]) torch.Size([32])
# torch.cuda.LongTensor torch.cuda.LongTensor
# torch.Size([32]) torch.Size([32])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 13
#      11 print(predicted.type(), y.type())
#      12 print(predicted.shape, y.shape)
# ---> 13 print((predicted == y).all(1).type())
#      14 print((predicted == y).all(1).shape)
#      15 correct += torch.sum( (predicted == y) )
#
# IndexError: Dimension out of range (expected to be in range of [-1, 0], but got 1)

# %%
# 测试网络
correct = 0
total = 0
with torch.no_grad(): # 该局部关闭梯度计算功能
    for (x, y) in test_loader: # 获取小批次的 x 与 y
        x, y = x.to('cuda:0'), y.to('cuda:0')
        Pred = model(x) # 一次前向传播（小批量）  
        _, predicted = torch.max(Pred.data, dim=1)
        print(Pred.shape, predicted.shape, y.shape) 
        print(Pred[0]) 
        print(predicted[0])  
        print(y[0])  
        print("\n" "\n" "\n")          
        correct += torch.sum( (predicted == y) )
        total += y.size(0) 
print(f'测试集精准度: {100*correct/total} %')
# Out:
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ -1.0322,   0.0128,   3.2546,   3.8886,  -6.5023,  -2.8038, -10.8745,
#          10.9349,  -2.4017,   2.5305], device='cuda:0')
# tensor(7, device='cuda:0')
# tensor(7, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ -5.5335,   0.4379,  -2.1363,  13.2028,  -7.7333,   7.3093, -10.8330,
#          -2.4855,   4.2757,   4.0869], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ -5.1746,   2.3380,   2.3739,   4.0873,  -2.7718,  -5.6470, -12.6502,
#          12.1036,  -2.0378,   4.8565], device='cuda:0')
# tensor(7, device='cuda:0')
# tensor(7, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-6.4334,  4.2927, -2.6381,  1.8912,  1.5940,  0.5524, -4.0676,  1.4546,
#          1.9200,  2.1649], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-3.0821, -0.8277,  1.5920,  3.8923, -7.0041,  2.3101, -6.1523, -6.0264,
#         13.0722,  1.6409], device='cuda:0')
# tensor(8, device='cuda:0')
# tensor(8, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-5.4337, -0.2102, -4.2000, -6.1505, 10.6076,  1.1529,  3.3302, -3.9897,
#          4.9393,  0.5406], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(4, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([10.4668, -7.6928,  3.9591, -2.7761, -4.8726,  0.9464,  1.6765, -1.9025,
#          0.2522, -1.3277], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-3.2341,  4.9737,  1.8494,  0.3353, -0.9356, -1.5643, -0.7448,  1.0739,
#          1.9025, -2.0439], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ -1.3693,   6.2890,  11.9270,   6.9358, -12.9984,  -4.6704,  -4.5436,
#           0.5708,   4.7589,  -5.6653], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(2, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-6.8027,  9.1565,  0.2375, -0.7844,  1.3719, -3.2926, -0.9233,  1.7473,
#          3.3980, -2.0242], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-5
device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(7, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 0.2777, -7.6576, -9.1203,  8.1907, -5.7317, 20.0869, -3.1972, -9.9482,
#          4.3789,  3.7190], device='cuda:0')
# tensor(5, device='cuda:0')
# tensor(5, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-5.7990, -0.5001, -2.1293, -3.0646, 11.4804, -3.4788, -1.2397,  0.5111,
#         -0.3813,  4.5574], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(4, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-1.0929, -3.5059, -0.4455, -3.2226,  8.5017,  0.2281,  3.9225, -3.2367,
#         -1.1195,  1.0488], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(4, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-2.1015, -0.8001, -3.6522, -1.3253,  0.5519, -0.5723, -8.0103,  9.4089,
#         -1.4717,  4.2609], device='cuda:0')
# tensor(7, device='cuda:0')
# tensor(7, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ -1.8573,   0.2564,   3.9226,  13.0803, -11.1078,   2.0475, -11.7815,
#           1.1943,   2.0547,   1.6727], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-2.3042, -5.0837, -3.1642, -8.2106, 12.7613, -1.2115,  2.2349, -1.8183,
#          1.6503,  3.3824], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(4, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ -3.8905,  -0.5357,   4.2503,  11.3890,  -8.8168,  -0.7136, -14.0050,
#           3.1667,   3.2214,   4.7076], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-1.1786, -8.0217, -1.2646,  1.1367,  1.3817, -1.1301, -8.9695,  2.6773,
#          1.5426,  9.7333], device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(9, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 4.7276, -8.2207,  1.2089, -3.6148,  4.4228, -0.7554,  1.5626, -1.7186,
#         -1.7615,  2.5089], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(4, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 1.4412, -1.5220,  4.3834, -3.4577,  0.4064,  2.9287, 12.0226, -8.4009,
#          2.1853, -6.1616], device='cuda:0')
# tensor(6, device='cuda:0')
# tensor(6, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 13.2772, -11.7768,   2.4772,  -3.2512,  -6.9080,   3.5667,   0.3971,
#          -0.5692,  -0.1360,  -0.1780], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-7.5189,  8.0553, -0.4640,  2.9897, -0.6641, -0.0370, -2.8202,  0.8598,
#          3.0154, -1.2216], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 15.2982, -11.6295,   4.2088,  -3.5165,  -8.2672,   3.5416,   2.0779,
#          -1.3790,  -0.5103,  -2.0057], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-4.7530,  3.4360,  2.8645,  4.2099, -4.4306, -4.3348, -9.9742, 10.0172,
#         -1.4793,  2.9335], device='cuda:0')
# tensor(7, device='cuda:0')
# tensor(7, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([  5.3844, -10.3351,   1.0110,  -3.5931,  -2.5862,   4.9380,   4.4699,
#         -12.1407,  10.8921,   1.2133], device='cuda:0')
# tensor(8, device='cuda:0')
# tensor(8, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 1.8122, -8.7868, -1.6796,  0.5982, -1.5056,  0.7811, -9.0842,  2.5537,
#          2.9498,  7.9942], device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(9, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-1.2115, -4.5191, -0.6737, -6.4241, 13.7653, -2.2314,  4.0803, -0.6725,
#         -3.4149,  1.7409], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(4, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-3.0209, -3.1625, -2.0670, -6.3406, 14.4175, -2.8165,  1.9802,  1.2113,
#         -3.0038,  2.9261], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(4, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-3.0644e+00, -5.5134e-03,  8.5661e-01,  2.1721e+00, -3.8353e+00,
#         -4.1439e+00, -1.2683e+01,  1.2831e+01, -1.5719e+00,  5.5236e+00],
#        device='cuda:0')
# tensor(7, device='cuda:0')
# tensor(7, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([  2.0320,   1.2246,  14.5939,   7.0238, -13.5314,  -6.9015,  -6.3663,
#           2.2092,   3.5352,  -3.6949], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(2, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ -2.7994,  -2.0034,   0.2770,  12.1810,  -9.2245,   4.5981, -11.9125,
#          -2.3279,   5.8376,   4.5181], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-1.5642, -0.1548,  1.1897,  4.0573, -5.4366,  2.2482, -3.2583, -6.4810,
#          9.1002,  0.4715], device='cuda:0')
# tensor(8, device='cuda:0')
# tensor(8, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 0.7639, -4.1578,  2.5201, -0.4088, -3.9796, -0.6054, -2.7012, -5.5640,
#         10.4455,  2.2617], device='cuda:0')
# tensor(8, device='cuda:0')
# tensor(8, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# ...
# tensor(8, device='cuda:0')
# tensor(8, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([
device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(9, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-5.7573,  9.2708,  2.7673, -0.9154,  0.4313, -4.2631,  0.4235,  1.7595,
#          2.6207, -3.8703], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([  2.5486,   1.3156,  15.1934,   6.1426, -13.0861,  -6.8976,  -4.6904,
#           2.3491,   2.4271,  -4.6210], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(2, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ -2.1514,  -1.4153,  -2.5285,   0.8492,  -2.0972,  -1.1950, -11.6921,
#          11.3985,  -1.4680,   5.7168], device='cuda:0')
# tensor(7, device='cuda:0')
# tensor(7, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-5.5876,  9.0233,  3.4943, -0.8836, -0.0802, -4.7203,  0.1482,  1.7914,
#          2.9887, -3.9987], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 0.8987,  1.0398, 16.3243,  5.0710, -8.0975, -8.5371, -2.6012,  0.7787,
#          1.6580, -4.5544], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(2, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-3.5862, -3.0971, -4.9121, -6.6723, 13.3352, -0.7502,  0.2275,  1.6277,
#         -0.8898,  3.7058], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(4, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-1.7333,  0.1427,  1.0553, 12.8409, -9.2291,  5.5031, -7.7423, -3.1138,
#          2.0139,  0.9401], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 2.7540, -4.5368,  3.5004, -4.7563,  5.4317,  1.2982, 11.7151, -7.2623,
#         -0.9190, -4.1428], device='cuda:0')
# tensor(6, device='cuda:0')
# tensor(6, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-0.4143, -7.6619, -2.9574, -0.3553,  0.8472,  0.7457, -8.6334,  2.8449,
#          2.6015,  8.6507], device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(9, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-2.7714, -5.0510, -4.0934, -6.6613, 13.7961, -0.5909,  1.1546, -0.7635,
#         -0.5150,  4.1991], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(4, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([13.2119, -9.0262,  4.3866, -3.3010, -5.8151,  1.5903,  2.0012, -0.6920,
#         -1.5781, -2.3499], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-0.4405,  0.7520,  9.0243,  4.9896, -7.7296, -6.8017, -8.5687,  5.2564,
#          1.8859,  0.6332], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(7, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ -2.6509,   0.4065,   2.0215,  16.1331, -12.1940,   7.7617,  -9.3718,
#          -6.9228,   5.8003,   0.3674], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-2.7051e+00, -2.5670e+00, -2.4773e-01, -6.9235e-01, -2.7385e+00,
#          3.5810e+00, -1.1107e-02, -9.2464e+00,  1.3568e+01,  1.2634e+00],
#        device='cuda:0')
# tensor(8, device='cuda:0')
# tensor(8, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-6.3388e+00,  9.1327e+00,  1.2148e+00, -3.3145e-01,  4.6526e-01,
#         -3.0415e+00, -8.5687e-03,  1.2240e+00,  3.0657e+00, -2.9626e+00],
#        device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-4.5310, -1.8924, -5.1528, -7.1461, 13.4492, -1.1583,  0.1896,  1.6386,
#          0.3921,  3.3925], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(4, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 0.5964, -4.0484, -5.8056,  2.8140, -3.7948, 13.6577,  0.0943, -7.5631,
#          4.8449,  0.4273], device='cuda:0')
# tensor(5, device='cuda:0')
# tensor(5, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ -5.6634,  -3.5194,  -5.7265,   0.0841,   4.6648,  -1.1577, -10.9437,
#           3.4368,   3.6563,  10.9112], device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(9, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-0.5435, -2.1312, -3.2844, -0.1699, -0.8960,  0.3313, -9.5951, 11.2014,
#         -3.4931,  4.4953], device='cuda:0')
# tensor(7, device='cuda:0')
# tensor(7, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 4.0291, -7.1154, -1.5578,  0.8959, -5.1152,  8.8743,  0.1891, -7.5946,
#          6.5622,  0.6222], device='cuda:0')
# tensor(5, device='cuda:0')
# tensor(8, device='cuda:0')
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 1.7042, -2.5743,  3.3138, -4.9806,  2.4096,  2.0460, 11.7443, -7.3769,
#          1.6437, -5.1125], device='cuda:0')
# tensor(6, device='cuda:0')
# tensor(6, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-4.2740, -3.1013, -4.0057, -4.4107, 11.8622, -0.7407, -1.2218,  0.1517,
#          0.4115,  4.7629], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(4, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-2.6799, -7.3256, -1.8220,  0.8931,  3.9539, -1.4192, -8.5687,  1.7829,
#          1.4346, 10.1714], device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(9, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-1.1934, -8.7139, -2.2363, -1.3715,  4.9466, -1.5348, -7.2333,  2.6083,
#          0.1845, 10.0447], device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(9, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([10.2628, -8.7983,  2.4277, -4.7834, -2.5468,  1.4310,  3.2714, -1.1206,
#         -1.1503, -1.2536], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-1.8524, -8.9131, -1.5510,  0.7879,  4.0216, -1.0071, -8.2404,  1.5888,
#          0.9456, 10.5228], device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(9, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 2.7037, -4.7228,  2.8711, -6.4805,  5.3231,  2.4749, 14.1795, -8.3107,
#          0.3443, -5.5298], device='cuda:0')
# tensor(6, device='cuda:0')
# tensor(6, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ -6.1188,  -2.2255,  -2.8371,  13.2196,  -6.3770,   3.3364, -18.1262,
#           2.6851,   3.6534,  10.1776], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 1.9365, -4.3030,  2.8628, -6.8801,  6.0603,  2.8587, 15.3072, -9.4014,
#          0.9995, -6.0851], device='cuda:0')
# tensor(6, device='cuda:0')
# tensor(6, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 1.0713, -3.3970, -5.2378,  2.5719, -2.5691, 11.1511, -0.9718, -4.0835,
#          1.9147,  0.4302], device='cuda:0')
# tensor(5, device='cuda:0')
# tensor(5, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 3.4090, -2.6188,  2.4626, -0.9904, -0.3713,  3.8042,  7.1918, -5.6241,
#         -0.7482, -4.2095], device='cuda:0')
# tensor(6, device='cuda:0')
# tensor(6, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-3.0911,  3.9977,  7.9940,  3.9596, -5.7330, -7.2708, -7.3358,  6.9533,
#          0.4689, -0.3947], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(2, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-4.5268,  9.3235, 11.0693,  4.7446, -9.2819, -8.0370, -4.8928,  2.8547,
#          5.1852, -5.3146], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(2, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-0.9180, -3.9665, -1.4640, -3.5496,  6.9494,  1.3258,  2.6326, -5.0183,
#          2.9202,  1.7326], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(4, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-5.0264,  7.5542,  2.6145,  0.4917, -0.7434, -3.9435, -2.0830,  2.6088,
#          2.2388, -2.1297], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-4.8298,  1.0869, -2.8580, -0.8586,  5.3223, -2.0726, -5.1631,  2.6404,
#          1.3883,  4.5394], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(4, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-0.7199, -2.6423,  0.3217,  2.6924, -5.9699,  5.1136, -1.6743, -8.9621,
#         11.3205,  0.8051], device='cuda:0')
# tensor(8, device='cuda:0')
# tensor(8, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-4.0239, -1.6203, -6.8355,  2.3237,  3.0222,  5.3942, -5.8355,  1.2478,
#         -0.1617,  5.8733], device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(9, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 6.2682, -7.3998,  1.4217, -2.5704, -1.6748,  3.3116,  6.1898, -7.9943,
#          3.3818, -0.9123], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(6, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([-1.0768, -1.0666,  1.4032,  0.9967, -4.7616,  0.7728, -3.5238, -5.1389,
#         10.5689,  1.1015], device='cuda:0')
# tensor(8, device='cuda:0')
# tensor(8, device='cuda:0')
#
#
#
#
# torch.Size([32, 10]) torch.Size([32]) torch.Size([32])
# tensor([ 15.2571, -10.5115,   5.3496,  -3.1885,  -8.2262,   2.6641,   2.8386,
#          -2.6480,  -0.1392,  -2.7548], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
#
#
#
#
# torch.Size([16, 10]) torch.Size([16]) torch.Size([16])
# tensor([-7.9635,  8.7412,  0.3042,  1.9981,  0.4517, -3.9208, -4.6007,  3.0124,
#          2.9614,  0.1544], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
#
#
#
#
# 测试集精准度: 96.95999908447266 %
